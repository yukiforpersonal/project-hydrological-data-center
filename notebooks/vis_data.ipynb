# %%
import pandas as pd
import requests
import pickle

# %%
data=pickle.load(open("df_九州.pkl","rb"))

# %%
data_temp=data[data.水系名=="天塩川"]

# %%
data_temp
# Out:
#                  観測所名 観測項目            観測所記号  水系名        河川名  \
# 0            誉平（ぽんぴら）   雨量  101011281104010  天塩川        天塩川
# 1              佐久（さく）   雨量  101011281104020  天塩川        天塩川
# 2        音威子府（おといねっぷ）   雨量  101011281104030  天塩川        天塩川
# 3          恩根内（おんねない）   雨量  101011281104040  天塩川        天塩川
# 4         小車岳（おぐるまだけ）   雨量  101011281104050  天塩川        天塩川
# 5        上仁宇布（かみにうっぷ）   雨量  101011281104060  天塩川    ペンケニウプ川
# 6      下川サンル（しもかわさんる）   雨量  101011281104070  天塩川       サンル川
# 7           名寄市（なよろし）   雨量  101011281104080  天塩川        天塩川
# 8          一の橋（いちのはし）   雨量  101011281104090  天塩川        名寄川
# 9            下川（しもかわ）   雨量  101011281104100  天塩川        名寄川
# 10         西多寄（にしたよろ）   雨量  101011281104110  天塩川        天塩川
# 11     下川パンケ（しもかわぱんけ）   雨量  101011281104120  天塩川     下川パンケ川
# 12      北温根別（きたおんねべつ）   雨量  101011281104140  天塩川       温根別川
# 13        士別東（しべつひがし）   雨量  101011281104160  天塩川        天塩川
# 14     岩尾内（廃止）（いわおない）   雨量  101011281104170  天塩川       岩尾内川
# ...
